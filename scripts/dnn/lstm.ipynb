# %%
import numpy as np 
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets

# %%
# NOTE current order of orderbook is ask1 ,bid1, ask2, bid2, which performs better than the ragular form.
# 股票预测很容易被local minimum卡住，需要更小的学习率

# %%
# X shape = ([price, volume], N, time_span, level)
# y shape = (N) binary label
i      = 5
stock  = 600030
Xtrain = np.load(f'dataset/{stock}-{i}.train.X.npy')
Ytrain = np.load(f'dataset/{stock}-{i}.train.y.npy')
Xtest  = np.load(f'dataset/{stock}-{i}.test.X.npy')
Ytest  = np.load(f'dataset/{stock}-{i}.test.y.npy')
Xtrain = np.log10(Xtrain + 1)
Xtest  = np.log10(Xtest + 1)
Xtrain.shape, Ytrain.shape, Xtest.shape, Ytest.shape
# Out:
# ((2, 54890, 20, 20), (54890,), (2, 13908, 20, 20), (13908,))

# %%
Xtrain = torch.from_numpy(Xtrain).float().permute(1, 0, 2, 3)
Ytrain = torch.from_numpy(Ytrain).long()
Xtest  = torch.from_numpy(Xtest).float().permute(1, 0, 2, 3)
Ytest  = torch.from_numpy(Ytest).long()

# %%
trainset = torch.utils.data.TensorDataset(Xtrain, Ytrain)
testset = torch.utils.data.TensorDataset(Xtest, Ytest)

# Create data loaders.
batch_size = 128
train_dataloader = DataLoader(trainset, batch_size=batch_size)
test_dataloader = DataLoader(testset, batch_size=batch_size)

# %%
class LSTM(nn.Module):
    
    def __init__(self, input_size:int, output_size:int, hidden_size=64,
                 num_layers=1, dropout=0):
        super().__init__()
        self.linear  = nn.Linear(hidden_size * 2, output_size)
        self.lstm1_1 = nn.LSTM(input_size, hidden_size, num_layers,
                               dropout=dropout, batch_first=True)
        self.lstm1_2 = nn.LSTM(input_size, hidden_size, num_layers,
                               dropout=dropout, batch_first=True)
        self.__device = device
          
    def forward(self, x):
        x1, x2 = x[:,0], x[:,1]
        x1, _ = self.lstm1_1(x1)
        x1 = x1[:,-1,:]
        x2, _ = self.lstm1_2(x2)
        x2 = x2[:,-1,:]
        x = torch.cat([x1, x2], dim=1)
        x = F.relu(x)
        x = self.linear(x)
        return F.softmax(x, dim=1)

# %%
# device = "cuda" if torch.cuda.is_available() else "cpu"
device = 'cpu'
print(f"Using {device} device")

torch.manual_seed(0)
model = LSTM(input_size=20, output_size=2).to(device)
print(model)
# Out:
# Using cpu device
# LSTM(
#   (linear): Linear(in_features=128, out_features=2, bias=True)
#   (lstm1_1): LSTM(20, 64, batch_first=True)
#   (lstm1_2): LSTM(20, 64, batch_first=True)
# )

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model):
    n = len(dataloader.dataset)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= n
    correct /= n
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 100
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=5e-5)

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    print("train ", end ='')
    test(train_dataloader, model)
    test(test_dataloader, model)
print("Done!")
# Out:
# acy: 63.4%, Avg loss: 0.005323
#
# Epoch 29
# -------------------------------
# loss: 0.765420  [    0/54890]
# loss: 0.661468  [12800/54890]
# loss: 0.665467  [25600/54890]
# loss: 0.692176  [38400/54890]
# loss: 0.688960  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005360
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005321
#
# Epoch 30
# -------------------------------
# loss: 0.767272  [    0/54890]
# loss: 0.660703  [12800/54890]
# loss: 0.664846  [25600/54890]
# loss: 0.692236  [38400/54890]
# loss: 0.688901  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005359
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005318
#
# Epoch 31
# -------------------------------
# loss: 0.769076  [    0/54890]
# loss: 0.659966  [12800/54890]
# loss: 0.664245  [25600/54890]
# loss: 0.692299  [38400/54890]
# loss: 0.688848  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005357
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005315
#
# Epoch 32
# -------------------------------
# loss: 0.770836  [    0/54890]
# loss: 0.659257  [12800/54890]
# loss: 0.663664  [25600/54890]
# loss: 0.692362  [38400/54890]
# loss: 0.688800  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005356
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005312
#
# Epoch 33
# -------------------------------
# loss: 0.772551  [    0/54890]
# loss: 0.658575  [12800/54890]
# loss: 0.663102  [25600/54890]
# loss: 0.692427  [38400/54890]
# loss: 0.688756  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005355
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005310
#
# Epoch 34
# -------------------------------
# loss: 0.774223  [    0/54890]
# loss: 0.657917  [12800/54890]
# loss: 0.662558  [25600/54890]
# loss: 0.692494  [38400/54890]
# loss: 0.688716  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005354
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005308
#
# Epoch 35
# -------------------------------
# loss: 0.775853  [    0/54890]
# loss: 0.657283  [12800/54890]
# loss: 0.662032  [25600/54890]
# loss: 0.692561  [38400/54890]
# loss: 0.688681  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005353
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005305
#
# Epoch 36
# -------------------------------
# loss: 0.777441  [    0/54890]
# loss: 0.656674  [12800/54890]
# loss: 0.661523  [25600/54890]
# loss: 0.692629  [38400/54890]
# loss: 0.688650  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005353
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005303
#
# Epoch 37
# -------------------------------
# loss: 0.778991  [    0/54890]
# loss: 0.656084  [12800/54890]
# loss: 0.661031  [25600/54890]
# loss: 0.692697  [38400/54890]
# loss: 0.688623  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005352
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005301
#
# Epoch 38
# -------------------------------
# loss: 0.780502  [    0/54890]
# loss: 0.655513  [12800/54890]
# loss: 0.660554  [25600/54890]
# loss: 0.692765  [38400/54890]
# loss: 0.688598  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005351
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005299
#
# Epoch 39
# -------------------------------
# loss: 0.781976  [    0/54890]
# loss: 0.654959  [12800/54890]
# loss: 0.660092  [25600/54890]
# loss: 0.692834  [38400/54890]
# loss: 0.688576  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005350
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005297
#
# Epoch 40
# -------------------------------
# loss: 0.783413  [    0/54890]
# loss: 0.654426  [12800/54890]
# loss: 0.659644  [25600/54890]
# loss: 0.692902  [38400/54890]
# loss: 0.688559  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005349
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005295
#
# Epoch 41
# -------------------------------
# loss: 0.784814  [    0/54890]
# loss: 0.653910  [12800/54890]
# loss: 0.659211  [25600/54890]
# loss: 0.692971  [38400/54890]
# loss: 0.688545  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005349
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005293
#
# Epoch 42
# -------------------------------
# loss: 0.786180  [    0/54890]
# loss: 0.653413  [12800/54890]
# loss: 0.658791  [25600/54890]
# loss: 0.693039  [38400/54890]
# loss: 0.688533  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005348
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005291
#
# Epoch 43
# -------------------------------
# loss: 0.787514  [    0/54890]
# loss: 0.652929  [12800/54890]
# loss: 0.658383  [25600/54890]
# loss: 0.693108  [38400/54890]
# loss: 0.688522  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005347
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005290
#
# Epoch 44
# -------------------------------
# loss: 0.788817  [    0/54890]
# loss: 0.652462  [12800/54890]
# loss: 0.657986  [25600/54890]
# loss: 0.693177  [38400/54890]
# loss: 0.688514  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005347
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005288
#
# Epoch 45
# -------------------------------
# loss: 0.790087  [    0/54890]
# loss: 0.652011  [12800/54890]
# loss: 0.657598  [25600/54890]
# loss: 0.693246  [38400/54890]
# loss: 0.688508  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005346
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005286
#
# Epoch 46
# -------------------------------
# loss: 0.791327  [    0/54890]
# loss: 0.651573  [12800/54890]
# loss: 0.657221  [25600/54890]
# loss: 0.693314  [38400/54890]
# loss: 0.688504  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005345
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005285
#
# Epoch 47
# -------------------------------
# loss: 0.792537  [    0/54890]
# loss: 0.651148  [12800/54890]
# loss: 0.656854  [25600/54890]
# loss: 0.693383  [38400/54890]
# loss: 0.688502  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005345
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005283
#
# Epoch 48
# -------------------------------
# loss: 0.793716  [    0/54890]
# loss: 0.650737  [12800/54890]
# loss: 0.656498  [25600/54890]
# loss: 0.693454  [38400/54890]
# loss: 0.688502  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005344
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005282
#
# Epoch 49
# -------------------------------
# loss: 0.794866  [    0/54890]
# loss: 0.650339  [12800/54890]
# loss: 0.656152  [25600/54890]
# loss: 0.693522  [38400/54890]
# loss: 0.688504  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005344
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005280
#
# Epoch 50
# -------------------------------
# loss: 0.795988  [    0/54890]
# loss: 0.649952  [12800/54890]
# loss: 0.655815  [25600/54890]
# loss: 0.693588  [38400/54890]
# loss: 0.688507  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005343
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005279
#
# Epoch 51
# -------------------------------
# loss: 0.797084  [    0/54890]
# loss: 0.649579  [12800/54890]
# loss: 0.655491  [25600/54890]
# loss: 0.693653  [38400/54890]
# loss: 0.688511  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005343
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005278
#
# Epoch 52
# -------------------------------
# loss: 0.798153  [    0/54890]
# loss: 0.649214  [12800/54890]
# loss: 0.655181  [25600/54890]
# loss: 0.693719  [38400/54890]
# loss: 0.688515  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005342
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005276
#
# Epoch 53
# -------------------------------
# loss: 0.799198  [    0/54890]
# loss: 0.648863  [12800/54890]
# loss: 0.654886  [25600/54890]
# loss: 0.693781  [38400/54890]
# loss: 0.688520  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005342
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005275
#
# Epoch 54
# -------------------------------
# loss: 0.800218  [    0/54890]
# loss: 0.648527  [12800/54890]
# loss: 0.654604  [25600/54890]
# loss: 0.693844  [38400/54890]
# loss: 0.688528  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005342
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005274
#
# Epoch 55
# -------------------------------
# loss: 0.801215  [    0/54890]
# loss: 0.648199  [12800/54890]
# loss: 0.654329  [25600/54890]
# loss: 0.693905  [38400/54890]
# loss: 0.688536  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005341
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005273
#
# Epoch 56
# -------------------------------
# loss: 0.802187  [    0/54890]
# loss: 0.647881  [12800/54890]
# loss: 0.654062  [25600/54890]
# loss: 0.693965  [38400/54890]
# loss: 0.688546  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005341
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005272
#
# Epoch 57
# -------------------------------
# loss: 0.803136  [    0/54890]
# loss: 0.647575  [12800/54890]
# loss: 0.653801  [25600/54890]
# loss: 0.694024  [38400/54890]
# loss: 0.688557  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005340
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005271
#
# Epoch 58
# -------------------------------
# loss: 0.804063  [    0/54890]
# loss: 0.647278  [12800/54890]
# loss: 0.653549  [25600/54890]
# loss: 0.694084  [38400/54890]
# loss: 0.688568  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005340
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005270
#
# Epoch 59
# -------------------------------
# loss: 0.804968  [    0/54890]
# loss: 0.646989  [12800/54890]
# loss: 0.653304  [25600/54890]
# loss: 0.694144  [38400/54890]
# loss: 0.688579  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005340
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005269
#
# Epoch 60
# -------------------------------
# loss: 0.805851  [    0/54890]
# loss: 0.646710  [12800/54890]
# loss: 0.653063  [25600/54890]
# loss: 0.694205  [38400/54890]
# loss: 0.688591  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005339
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005268
#
# Epoch 61
# -------------------------------
# loss: 0.806714  [    0/54890]
# loss: 0.646440  [12800/54890]
# loss: 0.652828  [25600/54890]
# loss: 0.694264  [38400/54890]
# loss: 0.688603  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005339
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005267
#
# Epoch 62
# -------------------------------
# loss: 0.807558  [    0/54890]
# loss: 0.646181  [12800/54890]
# loss: 0.652599  [25600/54890]
# loss: 0.694323  [38400/54890]
# loss: 0.688617  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005339
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005266
#
# Epoch 63
# -------------------------------
# loss: 0.808382  [    0/54890]
# loss: 0.645937  [12800/54890]
# loss: 0.652376  [25600/54890]
# loss: 0.694382  [38400/54890]
# loss: 0.688630  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005338
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005265
#
# Epoch 64
# -------------------------------
# loss: 0.809187  [    0/54890]
# loss: 0.645708  [12800/54890]
# loss: 0.652158  [25600/54890]
# loss: 0.694440  [38400/54890]
# loss: 0.688645  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005338
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005264
#
# Epoch 65
# -------------------------------
# loss: 0.809972  [    0/54890]
# loss: 0.645490  [12800/54890]
# loss: 0.651945  [25600/54890]
# loss: 0.694497  [38400/54890]
# loss: 0.688659  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005338
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005263
#
# Epoch 66
# -------------------------------
# loss: 0.810739  [    0/54890]
# loss: 0.645276  [12800/54890]
# loss: 0.651738  [25600/54890]
# loss: 0.694554  [38400/54890]
# loss: 0.688674  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005337
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005262
#
# Epoch 67
# -------------------------------
# loss: 0.811488  [    0/54890]
# loss: 0.645074  [12800/54890]
# loss: 0.651537  [25600/54890]
# loss: 0.694610  [38400/54890]
# loss: 0.688688  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005337
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005262
#
# Epoch 68
# -------------------------------
# loss: 0.812220  [    0/54890]
# loss: 0.644886  [12800/54890]
# loss: 0.651341  [25600/54890]
# loss: 0.694665  [38400/54890]
# loss: 0.688703  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005337
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005261
#
# Epoch 69
# -------------------------------
# loss: 0.812935  [    0/54890]
# loss: 0.644703  [12800/54890]
# loss: 0.651151  [25600/54890]
# loss: 0.694719  [38400/54890]
# loss: 0.688718  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005337
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005260
#
# Epoch 70
# -------------------------------
# loss: 0.813634  [    0/54890]
# loss: 0.644519  [12800/54890]
# loss: 0.650965  [25600/54890]
# loss: 0.694772  [38400/54890]
# loss: 0.688734  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005336
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005259
#
# Epoch 71
# -------------------------------
# loss: 0.814316  [    0/54890]
# loss: 0.644340  [12800/54890]
# loss: 0.650784  [25600/54890]
# loss: 0.694825  [38400/54890]
# loss: 0.688750  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005336
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005259
#
# Epoch 72
# -------------------------------
# loss: 0.814983  [    0/54890]
# loss: 0.644159  [12800/54890]
# loss: 0.650608  [25600/54890]
# loss: 0.694875  [38400/54890]
# loss: 0.688766  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005336
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005258
#
# Epoch 73
# -------------------------------
# loss: 0.815632  [    0/54890]
# loss: 0.643981  [12800/54890]
# loss: 0.650436  [25600/54890]
# loss: 0.694925  [38400/54890]
# loss: 0.688782  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005336
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005257
#
# Epoch 74
# -------------------------------
# loss: 0.816268  [    0/54890]
# loss: 0.643808  [12800/54890]
# loss: 0.650269  [25600/54890]
# loss: 0.694974  [38400/54890]
# loss: 0.688798  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005335
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005257
#
# Epoch 75
# -------------------------------
# loss: 0.816888  [    0/54890]
# loss: 0.643635  [12800/54890]
# loss: 0.650106  [25600/54890]
# loss: 0.695023  [38400/54890]
# loss: 0.688814  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005335
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005256
#
# Epoch 76
# -------------------------------
# loss: 0.817493  [    0/54890]
# loss: 0.643463  [12800/54890]
# loss: 0.649947  [25600/54890]
# loss: 0.695072  [38400/54890]
# loss: 0.688830  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005335
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005256
#
# Epoch 77
# -------------------------------
# loss: 0.818084  [    0/54890]
# loss: 0.643295  [12800/54890]
# loss: 0.649791  [25600/54890]
# loss: 0.695120  [38400/54890]
# loss: 0.688847  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005335
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005255
#
# Epoch 78
# -------------------------------
# loss: 0.818661  [    0/54890]
# loss: 0.643129  [12800/54890]
# loss: 0.649641  [25600/54890]
# loss: 0.695167  [38400/54890]
# loss: 0.688863  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005335
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005254
#
# Epoch 79
# -------------------------------
# loss: 0.819224  [    0/54890]
# loss: 0.642965  [12800/54890]
# loss: 0.649495  [25600/54890]
# loss: 0.695213  [38400/54890]
# loss: 0.688879  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005334
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005254
#
# Epoch 80
# -------------------------------
# loss: 0.819773  [    0/54890]
# loss: 0.642803  [12800/54890]
# loss: 0.649353  [25600/54890]
# loss: 0.695258  [38400/54890]
# loss: 0.688895  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005334
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005253
#
# Epoch 81
# -------------------------------
# loss: 0.820309  [    0/54890]
# loss: 0.642645  [12800/54890]
# loss: 0.649215  [25600/54890]
# loss: 0.695302  [38400/54890]
# loss: 0.688910  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005334
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005253
#
# Epoch 82
# -------------------------------
# loss: 0.820832  [    0/54890]
# loss: 0.642490  [12800/54890]
# loss: 0.649080  [25600/54890]
# loss: 0.695346  [38400/54890]
# loss: 0.688926  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005334
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005252
#
# Epoch 83
# -------------------------------
# loss: 0.821343  [    0/54890]
# loss: 0.642342  [12800/54890]
# loss: 0.648949  [25600/54890]
# loss: 0.695387  [38400/54890]
# loss: 0.688942  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005334
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005252
#
# Epoch 84
# -------------------------------
# loss: 0.821842  [    0/54890]
# loss: 0.642198  [12800/54890]
# loss: 0.648822  [25600/54890]
# loss: 0.695428  [38400/54890]
# loss: 0.688957  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005333
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005251
#
# Epoch 85
# -------------------------------
# loss: 0.822329  [    0/54890]
# loss: 0.642054  [12800/54890]
# loss: 0.648699  [25600/54890]
# loss: 0.695469  [38400/54890]
# loss: 0.688972  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005333
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005251
#
# Epoch 86
# -------------------------------
# loss: 0.822804  [    0/54890]
# loss: 0.641914  [12800/54890]
# loss: 0.648580  [25600/54890]
# loss: 0.695509  [38400/54890]
# loss: 0.688988  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005333
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005250
#
# Epoch 87
# -------------------------------
# loss: 0.823268  [    0/54890]
# loss: 0.641778  [12800/54890]
# loss: 0.648463  [25600/54890]
# loss: 0.695548  [38400/54890]
# loss: 0.689003  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005333
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005250
#
# Epoch 88
# -------------------------------
# loss: 0.823721  [    0/54890]
# loss: 0.641641  [12800/54890]
# loss: 0.648350  [25600/54890]
# loss: 0.695586  [38400/54890]
# loss: 0.689017  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005333
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005249
#
# Epoch 89
# -------------------------------
# loss: 0.824162  [    0/54890]
# loss: 0.641509  [12800/54890]
# loss: 0.648239  [25600/54890]
# loss: 0.695623  [38400/54890]
# loss: 0.689032  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005333
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005249
#
# Epoch 90
# -------------------------------
# loss: 0.824594  [    0/54890]
# loss: 0.641379  [12800/54890]
# loss: 0.648134  [25600/54890]
# loss: 0.695660  [38400/54890]
# loss: 0.689046  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005332
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005249
#
# Epoch 91
# -------------------------------
# loss: 0.825015  [    0/54890]
# loss: 0.641253  [12800/54890]
# loss: 0.648033  [25600/54890]
# loss: 0.695694  [38400/54890]
# loss: 0.689060  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005332
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005248
#
# Epoch 92
# -------------------------------
# loss: 0.825425  [    0/54890]
# loss: 0.641129  [12800/54890]
# loss: 0.647934  [25600/54890]
# loss: 0.695729  [38400/54890]
# loss: 0.689074  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005332
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005248
#
# Epoch 93
# -------------------------------
# loss: 0.825826  [    0/54890]
# loss: 0.641010  [12800/54890]
# loss: 0.647837  [25600/54890]
# loss: 0.695763  [38400/54890]
# loss: 0.689088  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005332
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005247
#
# Epoch 94
# -------------------------------
# loss: 0.826218  [    0/54890]
# loss: 0.640893  [12800/54890]
# loss: 0.647743  [25600/54890]
# loss: 0.695797  [38400/54890]
# loss: 0.689102  [51200/54890]
# train Test Error:
#  Accuracy: 58.0%, Avg loss: 0.005332
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 0.005247
#
# Epoch 95
# -------------------------------
# loss: 0.826601  [    0/54890]
# loss: 0.640782  [12800/54890]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-476f87a0e2d3> in <module>
#       5 for t in range(epochs):
#       6     print(f"Epoch {t+1}\n-------------------------------")
# ----> 7     train(train_dataloader, model, loss_fn, optimizer)
#       8     print("train ", end ='')
#       9     test(train_dataloader, model)
#
# <ipython-input-8-809f5fd0a98a> in train(dataloader, model, loss_fn, optimizer)
#      10         # Backpropagation
#      11         optimizer.zero_grad()
# ---> 12         loss.backward()
#      13         optimizer.step()
#      14
#
# ~/miniconda3/envs/pytorch17/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/miniconda3/envs/pytorch17/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:
